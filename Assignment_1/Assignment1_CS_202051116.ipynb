# %% [markdown]
# ## Data Analysis and Visualization (CS312)
# ## Assignment : 1
#
# ### Assignment Description and objective
#
# The assignment consists of two data files (a csv and a json). Both the file consists of District Level Manufacturing (json file) and Service (csv) MSME Registered Enterprises under UDYAM Registration till last date. MSME stands for Micro, Small and Medium Enterprise.
#  - Json file: Number of Manufacturing MSME
#  - CSV file: Number of Service MSME

# %% [markdown]
# ## Import Librarie's

# %%
import pandas as pd
import json
import sys

# %% [markdown]
# # TASK : 1
# ### 1 : Create two data frames by reading above two files.

# %%
dataframe1 = pd.read_csv(r"C:\Users\lenovo\OneDrive\Desktop\Data_analysis_and_visualization\Assignment_1\district_level_service_msme - district_level_service_msme.csv")

# %%
dataframe1.head()
# Out:
#        STATE_NAME  Lg_Dist_Code  DISTRICT_NAME  MICRO  SMALL  MEDIUM  Total  \
# 0  ANDHRA PRADESH           502     ANANTHAPUR   7797    238      10   8045
# 1  ANDHRA PRADESH           503        CHITOOR   9623    351      19   9993
# 2  ANDHRA PRADESH           505  EAST GODAVARI  12347    615      49  13011
# 3  ANDHRA PRADESH           506         GUNTUR  11386    630      53  12069
# 4  ANDHRA PRADESH           510        KRISHNA  15189   1007      79  16275
#
#   Last_Updated
# 0   2022-01-11
# 1   2022-01-11
# 2   2022-01-11
# 3   2022-01-11
# 4   2022-01-11

# %%
with open(r"C:\Users\lenovo\OneDrive\Desktop\Data_analysis_and_visualization\Assignment_1\district_level_manufacturing_msme.json") as data_file:
    data = json.load(data_file)

# %%
data
# Out:
# {'fields': [{'id': 'a', 'label': 'STATE_NAME', 'type': 'string'},
#   {'id': 'b', 'label': 'Lg_Dist_Code', 'type': 'string'},
#   {'id': 'c', 'label': 'DISTRICT_NAME', 'type': 'string'},
#   {'id': 'd', 'label': 'MICRO', 'type': 'string'},
#   {'id': 'e', 'label': 'SMALL', 'type': 'string'},
#   {'id': 'f', 'label': 'MEDIUM', 'type': 'string'},
#   {'id': 'g', 'label': 'Total', 'type': 'string'},
#   {'id': 'h', 'label': 'Last_Updated', 'type': 'string'}],
#  'data': [['ANDHRA PRADESH',
#    '502',
#    'ANANTHAPUR',
#    '11370',
#    '483',
#    '33',
#    '11886',
#    '2022-01-11'],
#   ['ANDHRA PRADESH',
#    '503',
#    'CHITOOR',
#    '13037',
#    '592',
#    '51',
#    '13680',
#    '2022-01-11'],
#   ['ANDHRA PRADESH',
#    '505',
#    'EAST GODAVARI',
#    '16711',
#    '1044',
#    '123',
#    '17878',
#    '2022-01-11'],
#   ['ANDHRA PRADESH',
#    '506',
#    'GUNTUR',
#    '15955',
#    '1678',
#    '169',
#    '17802',
#    '2022-01-11'],
#   ['ANDHRA PRADESH',
# ...

# %%
columns=pd.DataFrame(data["fields"])["label"].tolist()
dataframe2 = pd.DataFrame(data["data"],columns=columns)

# %%
dataframe2.head()
# Out:
#        STATE_NAME Lg_Dist_Code  DISTRICT_NAME  MICRO SMALL MEDIUM  Total  \
# 0  ANDHRA PRADESH          502     ANANTHAPUR  11370   483     33  11886
# 1  ANDHRA PRADESH          503        CHITOOR  13037   592     51  13680
# 2  ANDHRA PRADESH          505  EAST GODAVARI  16711  1044    123  17878
# 3  ANDHRA PRADESH          506         GUNTUR  15955  1678    169  17802
# 4  ANDHRA PRADESH          510        KRISHNA  20460  1673    165  22298
#
#   Last_Updated
# 0   2022-01-11
# 1   2022-01-11
# 2   2022-01-11
# 3   2022-01-11
# 4   2022-01-11

# %% [markdown]
# ## Conclusion .
# Here we successfully created two data frame.
#  - First we read csv file and created dataframe1
#  - Secondly we read json file and created dataframe2

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------------

# %%
dataframe1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 738 entries, 0 to 737
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   STATE_NAME     738 non-null    object
#  1   Lg_Dist_Code   738 non-null    int64
#  2   DISTRICT_NAME  738 non-null    object
#  3   MICRO          738 non-null    int64
#  4   SMALL          738 non-null    int64
#  5   MEDIUM         738 non-null    int64
#  6   Total          738 non-null    int64
#  7   Last_Updated   738 non-null    object
# dtypes: int64(5), object(3)
# memory usage: 46.2+ KB

# %%
dataframe2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 737 entries, 0 to 736
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   STATE_NAME     737 non-null    object
#  1   Lg_Dist_Code   737 non-null    object
#  2   DISTRICT_NAME  737 non-null    object
#  3   MICRO          737 non-null    object
#  4   SMALL          737 non-null    object
#  5   MEDIUM         737 non-null    object
#  6   Total          737 non-null    object
#  7   Last_Updated   737 non-null    object
# dtypes: object(8)
# memory usage: 46.2+ KB

# %% [markdown]
# # TASK : 2
# ### 2. Find out total ”Small” Manufacturing MSME in India.

# %%
Total_small_Manufacturing_from_dataframe2 = dataframe2['SMALL'].sum()
Total_small_Manufacturing_from_dataframe2
# Out:
# '...'

# %% [markdown]
# # NOTE :
# ###### In dataframe2 if we see column 'SMALL' it is in object data type format if we get sum it it will return a big string. that we can see in our aboce cell therefore, but we want summation of all cell because of string it is concatenated the string. which we aren't required thus, for removeing this error we will change it's datatype to numeric value using function to_numeric which is inbuild func of pandas.

# %%
Task2 = dataframe2["SMALL"]
Task2 = pd.to_numeric(Task2)
#here we successfull converted string value to numeric value now we can do it's summation.

# Executing Sum Here .
print("Total SMALL Manufacturing MSME in india : ", Task2.sum())
# Out:
# Total SMALL Manufacturing MSME in india :  317222

# %% [markdown]
# ## Conclusion .
# Here we successfully calculated the total Small manufacturing msme in india.
#  - Total SMAll Manufacturing MSME in India : 317222

# %% [markdown]
# # -----------------------------------------------------------------------------------------------------------

# %% [markdown]
# # TASK : 3
# ### 3. Create a dataframe having state wise total number of ”Micro”,”Small” and ”Medium” Services MSE (as shown below) and save the results as a CSV file.
# ![image.png](attachment:image.png)

# %%
data_source = {'State': dataframe1["STATE_NAME"], 'Micro': dataframe1["MICRO"], 'Small': dataframe1["SMALL"],
               'Medium': dataframe1["MEDIUM"]}

# %%
Task3 = pd.DataFrame(data_source)
Task3 = Task3.groupby(by="State")[['Micro','Small','Medium']].sum()
Task3.to_csv("task3.csv",index=False)

# %%
Task3.head()
# Out:
#                               Micro  Small  Medium
# State
# ANDAMAN AND NICOBAR ISLANDS    2884    111       6
# ANDHRA PRADESH               115320   5799     422
# ARUNACHAL PRADESH              1201     53       6
# ASSAM                         41051   2182     200
# BIHAR                        167835   3908     245

# %% [markdown]
# ## Conclusion .
#  - Here we successfully created dataframe as name "Task3" in which there has state wise "Micro", "Small", "Medium" service's available.
#  - Successfully converted dataframe into csv file and download it. in our system.

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # TASK : 4
# ### 4 : Join the both the data frame based on common STATE NAME, DISTRICT NAME, Lg Dist Code and Last Updated. The result should look like below. ”x” and ”y” in below image represent the manufacturing MSME and service MSME respectively.
# ![image2.png](attachment:image2.png)

# %% [markdown]
# - Here we want to merge dataframe's
# - but we can merge dataframe column with same data type
# - means obj merge with obj but obj is not merge with int
# - Therefore, we have to convert some column of dataframe2 to int data type like Lg_dist_court, small, large, medium etc.

# %%
dataframe2["MICRO"]=pd.to_numeric(dataframe2["MICRO"])
dataframe2["SMALL"]=pd.to_numeric(dataframe2["SMALL"])
dataframe2["MEDIUM"]=pd.to_numeric(dataframe2["MEDIUM"])
dataframe2["Lg_Dist_Code"]=pd.to_numeric(dataframe2["Lg_Dist_Code"])
dataframe2["Total"]=pd.to_numeric(dataframe2["Total"])

# %%
dataframe1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 738 entries, 0 to 737
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   STATE_NAME     738 non-null    object
#  1   Lg_Dist_Code   738 non-null    int64
#  2   DISTRICT_NAME  738 non-null    object
#  3   MICRO          738 non-null    int64
#  4   SMALL          738 non-null    int64
#  5   MEDIUM         738 non-null    int64
#  6   Total          738 non-null    int64
#  7   Last_Updated   738 non-null    object
# dtypes: int64(5), object(3)
# memory usage: 46.2+ KB

# %%
dataframe2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 737 entries, 0 to 736
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   STATE_NAME     737 non-null    object
#  1   Lg_Dist_Code   737 non-null    int64
#  2   DISTRICT_NAME  737 non-null    object
#  3   MICRO          737 non-null    int64
#  4   SMALL          737 non-null    int64
#  5   MEDIUM         737 non-null    int64
#  6   Total          737 non-null    int64
#  7   Last_Updated   737 non-null    object
# dtypes: int64(5), object(3)
# memory usage: 46.2+ KB

# %%
# Now we can merge both dataframe of same type as you can see in above two cell's that every column of dataframe1 has same
# data type with dataframe2 column's
Task4 = pd.merge(dataframe2,dataframe1, left_on=["STATE_NAME","Lg_Dist_Code","DISTRICT_NAME","Last_Updated"],right_on=["STATE_NAME","Lg_Dist_Code","DISTRICT_NAME","Last_Updated"])
Task4
# Out:
#          STATE_NAME  Lg_Dist_Code         DISTRICT_NAME  MICRO_x  SMALL_x  \
# 0    ANDHRA PRADESH           502            ANANTHAPUR    11370      483
# 1    ANDHRA PRADESH           503               CHITOOR    13037      592
# 2    ANDHRA PRADESH           505         EAST GODAVARI    16711     1044
# 3    ANDHRA PRADESH           506                GUNTUR    15955     1678
# 4    ANDHRA PRADESH           510               KRISHNA    20460     1673
# ..              ...           ...                   ...      ...      ...
# 717          LADAKH             9            LEH LADAKH     1493       35
# 718     LAKSHADWEEP           553  LAKSHADWEEP DISTRICT      150        0
# 719      PUDUCHERRY           598              KARAIKAL     1248       56
# 720      PUDUCHERRY           599                  MAHE       95       17
# 721      PUDUCHERRY           600           PONDICHERRY     7698      413
#
#      MEDIUM_x  Total_x Last_Updated  MICRO_y  SMALL_y  MEDIUM_y  Total_y
# ...

# %% [markdown]
# # Conclusion :
#  - We successfully merged dataframe2 with dataframe1 of same data type of column's

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------

# %% [markdown]
# # TASK : 5
# ### 5. Create a Pivot Table having rows STATE NAME and columns Service and Manufacturing ”MSME” as show in below. Use ”Sum” to add up district wise number.
# ![image3.png](attachment:image3.png)

# %%
Task5 = Task4.groupby("STATE_NAME")[["MEDIUM_x","MEDIUM_y","MICRO_x","MICRO_y","SMALL_x","SMALL_y"]].sum()
Task5
# Out:
#                              MEDIUM_x  MEDIUM_y  MICRO_x  MICRO_y  SMALL_x  \
# STATE_NAME
# ANDAMAN AND NICOBAR ISLANDS         7         6     3905     2884      140
# ANDHRA PRADESH                   1030       422   153814   115320    10599
# ARUNACHAL PRADESH                  11         6     2172     1201       99
# ASSAM                             309       200    65544    41051     3345
# BIHAR                             413       245   247394   167835     5226
# CHANDIGARH                        134        76    11435     9010     1007
# CHHATTISGARH                      566       257    74058    58905     4580
# DADAR AND NAGAR HAVELI             82         3     3730     2511      419
# DAMAN AND DIU                      56         2     1626      892      295
# DELHI                            2146      1134   145581    91019    16597
# GOA                                91        40    11556     8963      713
# ...

# %% [markdown]
# # Conclusion :
#  - We successfully created pivot table according to given condition's

# %% [markdown]
# # -----------------------------------------------------------------------------------------------------------

# %% [markdown]
# # -----------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Name : Mayank Mangal Mourya
# # Student id : 202051116
